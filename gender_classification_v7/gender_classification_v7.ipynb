# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('gender_classification_v7.csv')
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.tail()
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 4996          0                          0  Female
# 4997          0                          0  Female
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
df.shape
# Out:
# (5001, 8)

# %%
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1768

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# long_hair
# 1    2659
# 0     574
# Name: count, dtype: int64
# forehead_width_cm
# 11.9    100
# 12.6     99
# 11.8     98
# 14.1     98
# 12.5     97
# 13.2     97
# 13.6     95
# 13.5     95
# 11.6     95
# 12.1     95
# 12.0     95
# 14.2     95
# 13.3     93
# 11.5     93
# 12.8     92
# 12.2     91
# 14.0     91
# 13.7     90
# 13.8     89
# 13.4     87
# 13.9     87
# 12.7     85
# 13.1     85
# 12.9     84
# 12.3     83
# 13.0     83
# 11.7     81
# 12.4     81
# 14.3     81
# 11.4     53
# 14.9     51
# 15.5     49
# 15.4     48
# 14.5     47
# 15.3     46
# 15.1     45
# 15.2     45
# 14.4     45
# 14.6     44
# 15.0     42
# 14.8     42
# 14.7     41
# Name: count, dtype: int64
# forehead_height_cm
# 6.3    195
# 5.8    193
# 6.4    192
# 5.5    190
# 5.9    189
# 5.1    187
# 6.2    186
# 5.3    185
# 6.0    183
# 6.5    180
# 5.6    180
# 5.7    176
# 6.1    175
# 5.4    174
# 5.2    159
# 6.8     88
# 7.1     85
# 7.0     84
# 6.6     84
# 6.9     75
# 6.7     73
# ...

# %%
df.dtypes
# Out:
# long_hair                      int64
# forehead_width_cm            float64
# forehead_height_cm           float64
# nose_wide                      int64
# nose_long                      int64
# lips_thin                      int64
# distance_nose_to_lip_long      int64
# gender                        object
# dtype: object

# %%
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4986          1               11.7                 6.1          1          1
# 4990          1               12.6                 5.7          0          0
# 4992          1               14.1                 7.0          1          1
# 4993          1               11.6                 5.9          0          0
# 4995          1               12.3                 6.9          0          1
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["long_hair"],bins=20,kde=True)
plt.title("gender_classification_v7.csv")
plt.show()     
print(df['long_hair'].describe())
sns.kdeplot(df["long_hair"], shade=True)
plt.title("KDE Plot of long_hair")
plt.show()
# Out:
# count    3233.000000
# mean        0.822456
# std         0.382188
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: long_hair, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4168\1757337815.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["long_hair"], shade=True)

# %%
sns.histplot(df["forehead_width_cm"],bins=20,kde=True)
plt.title("gender_classification_v7.csv")
plt.show()     
print(df['forehead_width_cm'].describe())
sns.kdeplot(df["forehead_width_cm"], shade=True)
plt.title("KDE Plot of forehead_width_cm")
plt.show()
# Out:
# count    3233.000000
# mean       13.217198
# std         1.115993
# min        11.400000
# 25%        12.300000
# 50%        13.200000
# 75%        14.100000
# max        15.500000
# Name: forehead_width_cm, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4168\3523975360.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["forehead_width_cm"], shade=True)

# %%
sns.histplot(df["forehead_height_cm"],bins=20,kde=True)
plt.title("gender_classification_v7.csv")
plt.show()     
print(df['forehead_height_cm'].describe())
sns.kdeplot(df["forehead_height_cm"], shade=True)
plt.title("KDE Plot of forehead_height_cm")
plt.show()
# Out:
# count    3233.000000
# mean        5.966038
# std         0.549789
# min         5.100000
# 25%         5.500000
# 50%         5.900000
# 75%         6.400000
# max         7.100000
# Name: forehead_height_cm, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4168\2975957809.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["forehead_height_cm"], shade=True)

# %%
sns.histplot(df["nose_wide"],bins=20,kde=True)
plt.title("gender_classification_v7.csv")
plt.show()     
print(df['nose_wide'].describe())
sns.kdeplot(df["nose_wide"], shade=True)
plt.title("KDE Plot of nose_wide")
plt.show()
# Out:
# count    3233.000000
# mean        0.536344
# std         0.498755
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: nose_wide, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4168\3576988476.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["nose_wide"], shade=True)

# %%
sns.histplot(df["nose_long"],bins=20,kde=True)
plt.title("gender_classification_v7.csv")
plt.show()     
print(df['nose_long'].describe())
sns.kdeplot(df["nose_long"], shade=True)
plt.title("KDE Plot of nose_long")
plt.show()
# Out:
# count    3233.000000
# mean        0.557686
# std         0.496738
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: nose_long, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4168\426647823.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["nose_long"], shade=True)

# %%
sns.histplot(df["lips_thin"],bins=20,kde=True)
plt.title("gender_classification_v7.csv")
plt.show()     
print(df['lips_thin'].describe())
sns.kdeplot(df["lips_thin"], shade=True)
plt.title("KDE Plot of lips_thin")
plt.show()
# Out:
# count    3233.000000
# mean        0.538509
# std         0.498592
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: lips_thin, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4168\2163614713.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["lips_thin"], shade=True)

# %%
sns.histplot(df["distance_nose_to_lip_long"],bins=20,kde=True)
plt.title("gender_classification_v7.csv")
plt.show()     
print(df['distance_nose_to_lip_long'].describe())
sns.kdeplot(df["distance_nose_to_lip_long"], shade=True)
plt.title("KDE Plot of distance_nose_to_lip_long")
plt.show()
# Out:
# count    3233.000000
# mean        0.545314
# std         0.498019
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: distance_nose_to_lip_long, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_4168\2976065621.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["distance_nose_to_lip_long"], shade=True)

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["gender"])
plt.xticks(rotation=40)
plt.title("gender Count")
plt.show()
print(df['gender'].describe())
# Out:
# count     3233
# unique       2
# top       Male
# freq      1783
# Name: gender, dtype: object

# %%
Quatiles=['long_hair','forehead_width_cm','forehead_height_cm','nose_wide','nose_long','lips_thin','distance_nose_to_lip_long']
for i in Quatiles:

    sns.boxplot(y=df[i])
    plt.title(f'{i}')
    plt.show()

# %%
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4986          1               11.7                 6.1          1          1
# 4990          1               12.6                 5.7          0          0
# 4992          1               14.1                 7.0          1          1
# 4993          1               11.6                 5.9          0          0
# 4995          1               12.3                 6.9          0          1
#
# ...

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['gender']=lb.fit_transform(df['gender'])
print(lb.classes_)
# Out:
# ['Female' 'Male']

# %%
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4986          1               11.7                 6.1          1          1
# 4990          1               12.6                 5.7          0          0
# 4992          1               14.1                 7.0          1          1
# 4993          1               11.6                 5.9          0          0
# 4995          1               12.3                 6.9          0          1
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df=df[['nose_wide','nose_long','distance_nose_to_lip_long','gender']]
df
# Out:
#       nose_wide  nose_long  distance_nose_to_lip_long  gender
# 0             1          0                          1       1
# 1             0          0                          0       0
# 2             1          1                          1       1
# 3             0          1                          1       1
# 4             0          0                          0       0
# ...         ...        ...                        ...     ...
# 4986          1          1                          1       1
# 4990          0          0                          0       0
# 4992          1          1                          1       1
# 4993          0          0                          1       0
# 4995          0          1                          1       1
#
# [3233 rows x 4 columns]

# %% [markdown]
# # splitting

# %%
x=df.drop(columns=['gender'])
y=df['gender']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45,test_size=0.2)

# %%
x_train.shape
# Out:
# (2586, 4)

# %%
x_test.shape
# Out:
# (647, 4)

# %%
y_train.shape
# Out:
# (2586,)

# %%
y_test.shape
# Out:
# (647,)

# %% [markdown]
# # Model_Building

# %%
# K-Nearest Neighbor(KNN) Algorithm

from sklearn.neighbors import KNeighborsRegressor

knn=KNeighborsRegressor(n_neighbors=45)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=45)

# %%
knn.score(x_train,y_train)
# Out:
# 0.8526257191429045

# %%
knn.score(x_test,y_test)
# Out:
# 0.8266655993168961

# %%
y_pred=knn.predict(x_test)

# %%
y_pred
# Out:
# array([0.02222222, 0.53333333, 0.        , 1.        , 0.02222222,
#        0.02222222, 0.02222222, 0.62222222, 1.        , 0.02222222,
#        0.        , 0.02222222, 0.        , 1.        , 0.        ,
#        0.        , 0.02222222, 1.        , 1.        , 1.        ,
#        1.        , 0.62222222, 0.95555556, 0.02222222, 0.95555556,
#        0.95555556, 0.        , 0.6       , 1.        , 0.02222222,
#        1.        , 0.02222222, 0.95555556, 0.        , 1.        ,
#        0.        , 0.        , 1.        , 0.02222222, 0.02222222,
#        0.97777778, 0.        , 1.        , 0.        , 1.        ,
#        0.02222222, 0.        , 1.        , 1.        , 0.        ,
#        1.        , 1.        , 0.46666667, 0.        , 1.        ,
#        0.02222222, 1.        , 1.        , 0.95555556, 0.95555556,
#        0.        , 1.        , 0.95555556, 0.02222222, 0.        ,
#        0.97777778, 0.95555556, 0.97777778, 0.        , 1.        ,
# ...

# %%
new_data_point=np.array([[1,1,1,1]])

# %%
knn.predict(new_data_point)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([1.])

# %%
y_train
# Out:
# 4638    0
# 1385    1
# 847     1
# 520     0
# 3932    1
#        ..
# 670     1
# 2489    1
# 2084    0
# 3444    1
# 4525    1
# Name: gender, Length: 2586, dtype: int32

# %%
r = pd.DataFrame({'Actual Values':y_test,'Predicted Values':y_pred})

# %%
r
# Out:
#       Actual Values  Predicted Values
# 996               0          0.022222
# 1699              1          0.533333
# 179               0          0.000000
# 12                1          1.000000
# 2748              0          0.022222
# ...             ...               ...
# 1370              0          0.000000
# 4002              1          0.977778
# 559               1          0.622222
# 2025              1          1.000000
# 3624              0          0.000000
#
# [647 rows x 2 columns]
