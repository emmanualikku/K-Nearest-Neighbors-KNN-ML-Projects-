# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('Employee.csv')
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1889

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for columns in df.columns:
    print(df[columns].value_counts())
# Out:
# Education
# Bachelors    1971
# Masters       637
# PHD           156
# Name: count, dtype: int64
# JoiningYear
# 2017    662
# 2015    464
# 2013    396
# 2014    385
# 2016    310
# 2012    308
# 2018    239
# Name: count, dtype: int64
# City
# Bangalore    1171
# Pune          801
# New Delhi     792
# Name: count, dtype: int64
# PaymentTier
# 3    1976
# 2     570
# 1     218
# Name: count, dtype: int64
# Age
# 28    365
# 27    218
# 30    186
# 29    180
# 26    179
# 25    167
# 24    161
# 36    121
# 40    119
# 37    119
# 34    118
# 38    117
# 39    115
# 31    115
# 33    114
# 32    113
# 35    110
# 41     75
# 23     41
# 22     31
# Name: count, dtype: int64
# Gender
# Male      1529
# Female    1235
# Name: count, dtype: int64
# EverBenched
# No     2403
# Yes     361
# Name: count, dtype: int64
# ExperienceInCurrentDomain
# 2    681
# 5    470
# 3    451
# 1    433
# 4    425
# 0    287
# 7      9
# 6      8
# Name: count, dtype: int64
# LeaveOrNot
# 0    1676
# ...

# %%
df.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["JoiningYear"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['JoiningYear'].describe())
sns.kdeplot(df["JoiningYear"], shade=True)
plt.title("KDE Plot of JoiningYear")
plt.show()
# Out:
# count    2764.000000
# mean     2015.090449
# std         1.885943
# min      2012.000000
# 25%      2013.000000
# 50%      2015.000000
# 75%      2017.000000
# max      2018.000000
# Name: JoiningYear, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_18684\3555347288.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["JoiningYear"], shade=True)

# %%
sns.histplot(df["PaymentTier"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['PaymentTier'].describe())
sns.kdeplot(df["PaymentTier"], shade=True)
plt.title("KDE Plot of PaymentTier")
plt.show()
# Out:
# count    2764.000000
# mean        2.636035
# std         0.624001
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         3.000000
# Name: PaymentTier, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_18684\3038942735.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["PaymentTier"], shade=True)

# %%
sns.histplot(df["Age"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['Age'].describe())
sns.kdeplot(df["Age"], shade=True)
plt.title("KDE Plot of Age")
plt.show()
# Out:
# count    2764.000000
# mean       30.952967
# std         5.108872
# min        22.000000
# 25%        27.000000
# 50%        30.000000
# 75%        35.000000
# max        41.000000
# Name: Age, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_18684\2927997767.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["Age"], shade=True)

# %%
sns.histplot(df["ExperienceInCurrentDomain"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['ExperienceInCurrentDomain'].describe())
sns.kdeplot(df["ExperienceInCurrentDomain"], shade=True)
plt.title("KDE Plot of ExperienceInCurrentDomain")
plt.show()
# Out:
# count    2764.000000
# mean        2.644356
# std         1.610610
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max         7.000000
# Name: ExperienceInCurrentDomain, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_18684\568237011.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["ExperienceInCurrentDomain"], shade=True)

# %%
sns.histplot(df["LeaveOrNot"],bins=20,kde=True)
plt.title("Employee.csv")
plt.show()     
print(df['LeaveOrNot'].describe())
sns.kdeplot(df["LeaveOrNot"], shade=True)
plt.title("KDE Plot of LeaveOrNot")
plt.show()
# Out:
# count    2764.000000
# mean        0.393632
# std         0.488643
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: LeaveOrNot, dtype: float64
# C:\Users\hp\AppData\Local\Temp\ipykernel_18684\4102584986.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["LeaveOrNot"], shade=True)

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["Education"])
plt.xticks(rotation=40)
plt.title("Education Count")
plt.show()
print(df['Education'].describe())
# Out:
# count          2764
# unique            3
# top       Bachelors
# freq           1971
# Name: Education, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["City"])
plt.xticks(rotation=40)
plt.title("City Count")
plt.show()
print(df['City'].describe())
# Out:
# count          2764
# unique            3
# top       Bangalore
# freq           1171
# Name: City, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["Gender"])
plt.xticks(rotation=40)
plt.title("Gender Count")
plt.show()
print(df['Gender'].describe())
# Out:
# count     2764
# unique       2
# top       Male
# freq      1529
# Name: Gender, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df["EverBenched"])
plt.xticks(rotation=40)
plt.title("EverBenched Count")
plt.show()
print(df['EverBenched'].describe())
# Out:
# count     2764
# unique       2
# top         No
# freq      2403
# Name: EverBenched, dtype: object

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=df['Age'], y=df["City"],hue=df['Education'])
plt.xticks(rotation=45)
plt.title("Distribution by Age")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=df['City'], y=df["Age"],hue=df['LeaveOrNot'])
plt.xticks(rotation=45)
plt.title("Distribution by Age")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=df['JoiningYear'], y=df["Age"],hue=df['LeaveOrNot'])
plt.xticks(rotation=45)
plt.title("Distribution by Age")
plt.show()

# %%
Quatiles=['JoiningYear','PaymentTier','Age','ExperienceInCurrentDomain','LeaveOrNot']
for i in Quatiles:

    sns.boxplot(y=df[i])
    plt.title(f'{i}')
    plt.show()

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %%
df['Education'].unique()
# Out:
# array(['Bachelors', 'Masters', 'PHD'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Education']=lb.fit_transform(df['Education'])
print(lb.classes_)
# Out:
# ['Bachelors' 'Masters' 'PHD']

# %%
df['City'].unique()
# Out:
# array(['Bangalore', 'Pune', 'New Delhi'], dtype=object)

# %%
lb=LabelEncoder()
df['City']=lb.fit_transform(df['City'])
print(lb.classes_)
# Out:
# ['Bangalore' 'New Delhi' 'Pune']

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
lb=LabelEncoder()
df['Gender']=lb.fit_transform(df['Gender'])
print(lb.classes_)
# Out:
# ['Female' 'Male']

# %%
df['EverBenched'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
lb=LabelEncoder()
df['EverBenched']=lb.fit_transform(df['EverBenched'])
print(lb.classes_)
# Out:
# ['No' 'Yes']

# %%
df
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0             0         2017     0            3   34       1            0
# 1             0         2013     2            1   28       0            0
# 2             0         2014     1            3   38       0            0
# 3             1         2016     0            3   27       1            0
# 4             1         2017     2            3   24       1            1
# ...         ...          ...   ...          ...  ...     ...          ...
# 4645          1         2017     2            2   31       0            0
# 4647          0         2016     2            3   30       1            0
# 4649          1         2013     2            2   37       1            0
# 4650          1         2018     1            3   27       1            0
# 4651          0         2012     0            3   30       1            1
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df=df[['JoiningYear','City','PaymentTier','Age','Gender','LeaveOrNot']]

# %%
df
# Out:
#       JoiningYear  City  PaymentTier  Age  Gender  LeaveOrNot
# 0            2017     0            3   34       1           0
# 1            2013     2            1   28       0           1
# 2            2014     1            3   38       0           0
# 3            2016     0            3   27       1           1
# 4            2017     2            3   24       1           1
# ...           ...   ...          ...  ...     ...         ...
# 4645         2017     2            2   31       0           0
# 4647         2016     2            3   30       1           0
# 4649         2013     2            2   37       1           1
# 4650         2018     1            3   27       1           1
# 4651         2012     0            3   30       1           0
#
# [2764 rows x 6 columns]

# %% [markdown]
# # splitting

# %%
x=df.drop(columns=['LeaveOrNot'])
y=df['LeaveOrNot']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45,test_size=0.2)

# %%
x_train.shape
# Out:
# (2211, 5)

# %%
x_test.shape
# Out:
# (553, 5)

# %%
y_train.shape
# Out:
# (2211,)

# %%
y_test.shape
# Out:
# (553,)

# %% [markdown]
# # scalling

# %%
from sklearn.preprocessing import StandardScaler  # Import StandardScaler

scaler = StandardScaler()

# Fit the scaler on the training data and transform it
X_train_scaled = x_train.copy()
X_train_scaled[['JoiningYear','Age']] = scaler.fit_transform(
    x_train[['JoiningYear','Age']])

# Transform the testing data using the same scaler
X_test_scaled = x_test.copy()
X_test_scaled[['JoiningYear','Age']] = scaler.transform(
    x_test[['JoiningYear','Age']])

print(X_train_scaled)
print(X_test_scaled)
# Out:
#       JoiningYear  City  PaymentTier       Age  Gender
# 652     -0.054055     2            3 -1.146343       0
# 498      1.539494     2            3 -1.146343       1
# 2830    -0.585238     0            3 -0.162505       1
# 3387    -0.054055     1            3  1.214869       1
# 3948    -0.585238     0            3  1.214869       0
# ...           ...   ...          ...       ...     ...
# 168     -0.054055     0            3 -0.556040       1
# 973     -1.116422     2            2 -1.343110       0
# 3489     1.008311     0            3  0.624566       1
# 3216     1.008311     2            2  1.608404       1
# 4158    -1.647605     1            3  1.018101       0
#
# [2211 rows x 5 columns]
#       JoiningYear  City  PaymentTier       Age  Gender
# 3290    -1.116422     0            2  1.411636       0
# 3218    -1.647605     2            2  2.001939       0
# 3891    -1.116422     1            3  1.411636       0
# 3289    -1.647605     0            3  2.001939       1
# ...

# %%
X_test_scaled
# Out:
#       JoiningYear  City  PaymentTier       Age  Gender
# 3290    -1.116422     0            2  1.411636       0
# 3218    -1.647605     2            2  2.001939       0
# 3891    -1.116422     1            3  1.411636       0
# 3289    -1.647605     0            3  2.001939       1
# 4361    -0.585238     0            3  1.411636       1
# ...           ...   ...          ...       ...     ...
# 3543     0.477128     0            3  0.034263       1
# 3746    -0.054055     1            3  0.034263       1
# 2107     1.008311     2            2 -0.162505       1
# 3749    -1.647605     0            3  0.427798       1
# 3294     1.008311     1            3  1.608404       0
#
# [553 rows x 5 columns]

# %% [markdown]
# # Model_Building

# %%
# K-Nearest Neighbor(KNN) Algorithm

from sklearn.neighbors import KNeighborsRegressor

knn=KNeighborsRegressor(n_neighbors=41)

# %%
knn.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=41)

# %%
knn.score(X_train_scaled,y_train)
# Out:
# 0.2539643635626748

# %%
knn.score(X_test_scaled,y_test)
# Out:
# 0.2539485633000219

# %%
y_pred=knn.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0.3902439 , 0.58536585, 0.2195122 , 0.19512195, 0.2195122 ,
#        0.24390244, 0.65853659, 0.14634146, 0.29268293, 0.04878049,
#        0.36585366, 0.19512195, 0.3902439 , 0.34146341, 0.26829268,
#        0.24390244, 0.17073171, 0.48780488, 0.34146341, 0.2195122 ,
#        0.2195122 , 0.29268293, 0.75609756, 0.2195122 , 0.63414634,
#        0.17073171, 0.34146341, 0.29268293, 0.73170732, 0.43902439,
#        0.73170732, 0.19512195, 0.53658537, 0.3902439 , 0.2195122 ,
#        0.2195122 , 0.17073171, 0.73170732, 0.82926829, 0.41463415,
#        0.75609756, 0.56097561, 0.29268293, 0.17073171, 0.31707317,
#        0.51219512, 0.24390244, 0.58536585, 0.04878049, 0.43902439,
#        0.56097561, 0.58536585, 0.26829268, 0.12195122, 0.19512195,
#        0.73170732, 0.14634146, 0.29268293, 0.29268293, 0.75609756,
#        0.46341463, 0.26829268, 0.34146341, 0.36585366, 0.2195122 ,
#        0.34146341, 0.53658537, 0.75609756, 0.36585366, 0.19512195,
# ...

# %%
new_data_point=np.array([[0.477128,0,3,0.034263,1]])

# %%
knn.predict(new_data_point)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([0.24390244])

# %%
y_train
# Out:
# 652     1
# 498     1
# 2830    0
# 3387    0
# 3948    0
#        ..
# 168     0
# 973     1
# 3489    0
# 3216    0
# 4158    0
# Name: LeaveOrNot, Length: 2211, dtype: int64

# %%
r = pd.DataFrame({'Actual Values':y_test,'Predicted Values':y_pred})

# %%
r
# Out:
#       Actual Values  Predicted Values
# 3290              1          0.390244
# 3218              1          0.585366
# 3891              1          0.219512
# 3289              0          0.195122
# 4361              0          0.219512
# ...             ...               ...
# 3543              0          0.195122
# 3746              0          0.146341
# 2107              0          0.365854
# 3749              0          0.195122
# 3294              1          0.341463
#
# [553 rows x 2 columns]
